# %%
import sys
import os
from os.path import join
from pprint import pprint
sys.path.append(os.path.abspath("../../../"))
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML
from IPython.display import Markdown
import ipywidgets as iw
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xml.etree.ElementTree as et
from sklearn.model_selection import train_test_split

# %%
import usure.common.logging as usurelogging
from usure.config import config
from usure.classification.infrastructure import BasicSentenceCleaner
# Out:
# Using TensorFlow backend.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = lines => false

# %%
pd.set_option('colheader_justify', 'left')
pd.set_option('display.max_colwidth', 200)

# %%
def display_classes_and_total(df, description):
    display(Markdown(f'### {description}'))
    display(df.groupby(['polarity']).count())
    print(f"Total: {len(df)}")
    
def save_data_frame(df, name):
    df.to_csv(join(config.sets, f"{name}.csv"))

# %%
column_names = ["id", "text", "polarity"]

# %%
#https://stackoverflow.com/questions/17071871/select-rows-from-a-dataframe-based-on-values-in-a-column-in-pandas
#All
intertass_cr = pd.read_excel(join(config.classification, "country_CR_InterTASS.xls"),
                             usecols = ["id_str", "text", "polarity"],
                             sheet_name="tweets")
intertass_cr.columns = column_names
intertass_cr.set_index("id", inplace=True)
#train
intertass_cr_xml = et.parse(join(config.classification, "intertass-CR-train-tagged.xml"))
intertass_cr_xml_root = intertass_cr_xml.getroot()
intertass_cr_xml_dic = {
    "tweetid" : [element.text for element in intertass_cr_xml_root.findall("./tweet/tweetid")],
    "content" : [element.text for element in intertass_cr_xml_root.findall("./tweet/content")],
    "value" : [element.text for element in intertass_cr_xml_root.findall("./tweet/sentiment/polarity/value")]
}
intertass_cr_train = pd.DataFrame(intertass_cr_xml_dic)
intertass_cr_train.columns = column_names
intertass_cr_train.id = intertass_cr_train.id.astype('int64') 
intertass_cr_train.set_index("id", inplace=True)
#test
intertass_cr_test_xml = et.parse(join(config.classification, "intertass-CR-test.xml"))
intertass_cr_test_xml_root = intertass_cr_test_xml.getroot()
intertass_cr_test_xml_dic = {
    "tweetid" : [element.text for element in intertass_cr_test_xml_root.findall("./tweet/tweetid")],
    "content" : [element.text for element in intertass_cr_test_xml_root.findall("./tweet/content")],
    "value" : [element.text for element in intertass_cr_test_xml_root.findall("./tweet/sentiment/polarity/value")]
}
intertass_cr_test = pd.DataFrame(intertass_cr_test_xml_dic)
intertass_cr_test.columns = column_names
intertass_cr_test.id = intertass_cr_test.id.astype('int64') 
intertass_cr_test.set_index("id", inplace=True)

#display
display(Markdown(f'### Whole CR dataset'))
display(intertass_cr.groupby(['polarity']).count())
print(f"Total: {len(intertass_cr)}")
display(Markdown(f'### CR train dataset'))
display(intertass_cr_train.groupby(['polarity']).count())
print(f"Total: {len(intertass_cr_train)}")
display(Markdown(f'### CR test dataset'))
display(intertass_cr_test.groupby(['polarity']).count())
print(f"Total: {len(intertass_cr_test)}")
# Out:
# ### Whole CR dataset
#           text
# polarity
# N         912
# NEU       297
# NONE      447
# P         677
# Total: 2333
# ### CR train dataset
#           text
# polarity
# N         311
# NEU        94
# NONE      165
# P         230
# Total: 800
# ### CR test dataset
# Empty DataFrame
# Columns: [text]
# Index: []
# Total: 1233

# %%
train_not_in_all_set = intertass_cr_train.loc[~intertass_cr_train.index.isin(intertass_cr.index)]

test_not_in_all_set = intertass_cr_test.loc[~intertass_cr_test.index.isin(intertass_cr.index)]

# %%
shuffled_cr_test = intertass_cr.sample(frac=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(shuffled_cr_test["text"], 
                                                    shuffled_cr_test["polarity"], 
                                                    test_size=.5,
                                                    random_state=None,
                                                    shuffle=True,
                                                    stratify = shuffled_cr_test["polarity"])

# %%
X = pd.concat([X_train, y_train], axis=1, join='inner', ignore_index=False)
y = pd.concat([X_test, y_test], axis=1, join='inner', ignore_index=False)

# %%
display_classes_and_total(X, "New CR train set")
display_classes_and_total(y, "New CR test set")
# Out:
# ### New CR train set
#           text
# polarity
# N         456
# NEU       149
# NONE      223
# P         338
# Total: 1166
# ### New CR test set
#           text
# polarity
# N         456
# NEU       148
# NONE      224
# P         339
# Total: 1167

# %%
save_data_frame(X, "train")
save_data_frame(y, "test")

# %%
X
# Out:
#                    text                                                                                                                                        \
# id
# 792469210567888896                                                 1 minuto de silencio por los que trabajamos en horario de Mall y no podemos ver el clásico
# 815626648443830273                                                       Lo bueno es que desayuné al fin comida descente, y todos los ejercicios me han dado.
# 814711564150444032                                   @aniu96 @Chuz_CM Yo no puedo ingerir bebidas alcoholicas, ni marihuana, ni tabaco. Pero yo los acompaño.
# 803994481938853889                                            @bichoclarke leí el post equivocado aparentemente, me salieron los diseñadores snobs en mi feed
# 766318704288202753                                                                                             La verdad, es que estoy en mis mejores tiempos
# 807261162358394882                                                                                             A mí en serio esas cosas de ganar no se me dan
# 766097943954857984                                                                                             Extraño esas conversaciones largas con Vanessa
# 787984763713826816                                                    Entró a trabajar a la 1:30 p.m y yo en San Carlos Mi tío cree que voy a llegar puntual.
# 782808577471713281                                                                  @laufer4 le hiciste la noche a Ángel de Brito y la previa de la siguiente
# 808122577818439688                 Que triste cuando uno anda en una actividad y no tiene con quien bailar me veré muy rara bachateando sola en media pista ?
# 802383706665185280                                                                                        Yo perdiendo la cartera desde tiempos inmemorables.
# 776812177311223808                                                               @JosePablo noo! Soy la peor jajaja. Es que venía escuchando música lo siento
# 794509189246779392                                                                       Me cago en la restricción vehicular y que mi carro la tenga viernes.
# 802352213330784256                                                                                             9 horas de que se fue del pais y ya la extraño
# 790381773544837120                                                                    No se pueden ver 2 series a la vez es lo peor #prisonbreak #blackmirror
# 755954454910816256                                                                                                Me está llamando el Lively UP, reggae night
# 775116236912984064  @Manryev ¡Me alegra muchísimo que te gustara! Igualmente un placer saludarte La próxima que vengás a SJ avisá con tiempo y vamos por café
# 772167257497624576                                                Odio a la gente que tuitea postres. Yo necesitando algo dulce y solo un trident en el bolso
# 786438206778585088                                                 @PazBloise A mi me operan el lunes las 4 y leer esto es muy poco alentador Que sigas mejor
# 788164692376256512                                                                                                               @DCBlancoQ o ya lo está hola
# 778291153074401280                                      Esta ceniza me tiene mala ya. Ando con alegría y me arden los ojos, no puedo usar lentes de contacto.
# 815330846207053825                                                                                                            Como chiquito con juguete nuevo
# 756632241673908224                          Hoy me toca caminar desde SJO centro hasta la Sabana, por que movilidad urbana es mejor que obstinarse con presas
# 775467302057709568                                                             Hay algunas materias que no son digeribles, y una de esas es elementos activos
# 796205169134465024                                                              Turbada y espantada. Qué divino Niño ni sagrado manto ni qué albaharda vieja!
# 806210834485706752                                                                            @natalicruz98 que nos ponemos los que somos casi transparentes?
# 766080889847709697                            @Chepe_Centro Di tuve una reacción alérgica después de comer pasta 2 veces seguidas entonces esa es la sospecha
# 811955602046013440                                                       @edgumaco me acuerdo de la clínica Norza, el Peri, las casas en lotes llobet dañadas
# 773526199402311681                                             Mi cuerpo agradece demasiado el fruto del ejercicio pero mi guardarropa no Necesito ropa nueva
#
#                    polarity
# id
# 792469210567888896     N
# 815626648443830273     P
# 814711564150444032  NONE
# 803994481938853889     N
# 766318704288202753     P
# 807261162358394882     N
# 766097943954857984     N
# 787984763713826816  NONE
# 782808577471713281     P
# 808122577818439688     N
# 802383706665185280     N
# 776812177311223808     N
# 794509189246779392     N
# 802352213330784256     N
# 790381773544837120     N
# 755954454910816256     P
# 775116236912984064     P
# 772167257497624576     N
# 786438206778585088     N
# 788164692376256512  NONE
# 778291153074401280     N
# 756728107378225152     N
# 781021362022445056     N
# 767399570154205184     N
# 803214630113988608  NONE
# 783129155164598272     P
# 803781029718872065     N
# 804773102655852544   NEU
# 805030196265054209  NONE
# 802158982353788929     N
# ...                     ...
# 786066321008099328  NONE
# 809918358955184128     P
# 807537268235833344     N
# 787764658333560833     N
# 800576201244995584     N
# 806979643928670212  NONE
# 767109318428729344     P
# 775093665794445312  NONE
# 777366865979072512     N
# 768665015343808512     N
# 815651119284293633   NEU
# 815854866719510528     N
# 806110085948866560     N
# 783043022220951552     N
# 760565382893580288   NEU
# 793498295951826944     N
# 810335405480542208     P
# 816868854047666177     N
# 805614283509919744     N
# 796131167703617540  NONE
# 772865473645977600  NONE
# 778085405639966721   NEU
# 815330846207053825     P
# 756632241673908224     P
# 775467302057709568     N
# 796205169134465024     N
# 806210834485706752  NONE
# 766080889847709697     N
# 811955602046013440  NONE
# 773526199402311681   NEU
#
# [1166 rows x 2 columns]

# %%
intertass_cr["length"] = intertass_cr["text"].apply(lambda text: len(str.split(text)))
display(intertass_cr.describe())
# Out:
#        length
# count  2333.000000
# mean     14.035148
# std       5.689550
# min       4.000000
# 25%       9.000000
# 50%      13.000000
# 75%      18.000000
# max      33.000000

# %%
cleaner = BasicSentenceCleaner(config.assets)
intertass_cr_preprocecessed["text"] =  intertass_cr["text"].apply(cleaner.clean)

# %%
intertass_cr_preprocecessed["length"] = intertass_cr_preprocecessed["text"].apply(lambda text: len(str.split(text)))

# %%
intertass_cr_preprocecessed["length"].describe()
# Out:
# count    2333.000000
# mean        5.096014
# std         2.401266
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         7.000000
# max        15.000000
# Name: text, dtype: float64
