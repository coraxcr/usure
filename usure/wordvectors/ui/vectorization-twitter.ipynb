# %%
import sys
import os
from pprint import pprint
sys.path.append(os.path.abspath("../../../"))
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from usure.wordvectors.infrastructure import FileKeyedVectorsRep
from usure.wordvectors.ui import StatisticsReporter
from usure.config import config

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = lines => false

# %%
display(HTML("""<style>.output { display: flex;align-items: center;text-align: center; } </style>"""))

# %%
kvs_rep = FileKeyedVectorsRep(config.embeddings)
# %matplotlib notebook

# %% [markdown]
# # 1. Corpus:  Twitter

# %%
kvs_sw = kvs_rep.get("tweets.txt.usu.sw.kvs")
kvs_bg = kvs_rep.get("tweets.txt.usu.bw.kvs")
reporter_sw = StatisticsReporter(kvs_sw)
reporter_bw = StatisticsReporter(kvs_bg)

# %% [markdown]
# ## 1.1 Histograma

# %%
reporter_sw.plot_histogram(numb_top_words=65)
# Out:
# <img src="data:image/png;base64,..." width="1300">

# %% [markdown]
# ## 1.2 Nube de palabras

# %%
reporter_sw.plot_wordcloud(max_words=250)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# ## 1.3 Representacion vectorial en 2D

# %%
numb_words = 500
reporter_sw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
reporter_bw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="1184">

# %% [markdown]
# ## 1.4 Similitudes entre palabras

# %% [markdown]
# Ventanas pequeñas

# %%
palabra = "virtudes"
pprint(kvs_sw.wv.most_similar(palabra, topn=10))
# Out:
# [('defectos', 0.7491570711135864),
#  ('cualidades', 0.67535400390625),
#  ('gritemonos', 0.5531572103500366),
#  ('virtud', 0.5471464991569519),
#  ('virtudess', 0.5323187708854675),
#  ('admirarlos', 0.5179882645606995),
#  ('vistudes', 0.5105124115943909),
#  ('imperfecciones', 0.5096784234046936),
#  ('errores', 0.4833337664604187),
#  ('deciroslos', 0.48006683588027954)]

# %% [markdown]
# Ventana grande

# %%
pprint(kvs_bg.wv.most_similar(palabra, topn=10))
# Out:
# [('defectos', 0.7402721047401428),
#  ('cualidades', 0.6664875745773315),
#  ('virtud', 0.5506617426872253),
#  ('gritemonos', 0.5275282263755798),
#  ('imperfecciones', 0.5187901258468628),
#  ('admirarlos', 0.5073119401931763),
#  ('vistudes', 0.49819210171699524),
#  ('defecto', 0.47392183542251587),
#  ('errores', 0.4680948257446289),
#  ('deciroslos', 0.4531363248825073)]
