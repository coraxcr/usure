# %%
import sys
import os
from pprint import pprint
sys.path.append(os.path.abspath("../../../"))
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from usure.wordvectors.infrastructure import Word2VecDAO
from usure.wordvectors.ui import StatisticsReporter

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = lines => false

# %%
display(HTML("""<style>.output { display: flex;align-items: center;text-align: center; } </style>"""))
# Out:
# <style>.output { display: flex;align-items: center;text-align: center; } </style>

# %%
w2v_dao = Word2VecDAO()
# %matplotlib notebook

# %% [markdown]
# # 1. Corpus:  Twitter

# %%
w2v_sw = w2v_dao.get_model("twitter.sw")
w2v_bg = w2v_dao.get_model("twitter.bw")
reporter_sw = StatisticsReporter(w2v_sw.wv)
reporter_bw = StatisticsReporter(w2v_bg.wv)
#twitter = get_model("tweets")
#cardellino = get_model("xxx")

# %% [markdown]
# ## 1.1 Histograma

# %%
reporter_sw.plot_histogram(numb_top_words=65)
# Out:
# <img src="data:image/png;base64,..." width="1300">

# %% [markdown]
# ## 1.2 Nube de palabras

# %%
reporter_sw.plot_wordcloud(max_words=250)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# ## 1.3 Representacion vectorial en 2D

# %%
numb_words = 500
reporter_sw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
reporter_bw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="1466">

# %% [markdown]
# ## 1.4 Similitudes entre palabras

# %% [markdown]
# Ventanas pequeñas

# %%
palabra = "virtudes"
pprint(w2v_sw.wv.most_similar(palabra, topn=10))
# Out:
# [('defectos', 0.72459477186203),
#  ('cualidades', 0.6827132105827332),
#  ('gritemonos', 0.5363082885742188),
#  ('vistudes', 0.5267684459686279),
#  ('virtud', 0.5247147083282471),
#  ('virtudess', 0.5224429368972778),
#  ('imperfecciones', 0.513729453086853),
#  ('admirarlos', 0.49833858013153076),
#  ('pretectos', 0.475381076335907),
#  ('errores', 0.47391560673713684)]

# %% [markdown]
# Ventana grande

# %%
pprint(w2v_bg.wv.most_similar(palabra, topn=10))
# Out:
# [('defectos', 0.7520161271095276),
#  ('cualidades', 0.6703212261199951),
#  ('gritemonos', 0.5446420907974243),
#  ('virtud', 0.5359188914299011),
#  ('imperfecciones', 0.5329761505126953),
#  ('admirarlos', 0.5073632001876831),
#  ('vistudes', 0.48557525873184204),
#  ('defecto', 0.4762428402900696),
#  ('virtudess', 0.4688355326652527),
#  ('errores', 0.46736860275268555)]
