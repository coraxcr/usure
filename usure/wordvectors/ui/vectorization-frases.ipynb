# %%
import sys
import os
from pprint import pprint
sys.path.append(os.path.abspath("../../../"))
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from usure.wordvectors.infrastructure import FileKeyedVectorsRep
from usure.wordvectors.ui import StatisticsReporter
from usure.config import config

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = lines => false

# %%
display(HTML("""<style>.output { display: flex;align-items: center;text-align: center; } </style>"""))
# Out:
# <style>.output { display: flex;align-items: center;text-align: center; } </style>

# %%
kvs_rep = FileKeyedVectorsRep(config.embeddings)
# %matplotlib notebook

# %% [markdown]
# # 1. Corpus:  Gagini

# %%
kvs_sw = kvs_rep.get("frases2.csv.usu.2_w.kvs")
kvs_bg = kvs_rep.get("frases2.csv.usu.5_w.kvs")
reporter_sw = StatisticsReporter(kvs_sw)
reporter_bw = StatisticsReporter(kvs_bg)

# %% [markdown]
# ## 1.1 Histograma

# %%
reporter_sw.plot_histogram(numb_top_words=65)
# Out:
# <img src="data:image/png;base64,..." width="1299.9999718232596">

# %% [markdown]
# ## 1.2 Nube de palabras

# %%
reporter_sw.plot_wordcloud(max_words=250)
# Out:
# <img src="data:image/png;base64,..." width="1199.999973990701">

# %% [markdown]
# ## 1.3 Representacion vectorial en 2D

# %%
numb_words = 500
reporter_sw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="1122.727248392815">

# %%
reporter_bw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## 1.4 Similitudes entre palabras

# %% [markdown]
# Ventanas pequeñas

# %%
palabra = "diablo"
pprint(kvs_sw.wv.most_similar(palabra, topn=10))
# Out:
# [('corteza', 0.11774277687072754),
#  ('brava', 0.10023218393325806),
#  ('raja', 0.08862125128507614),
#  ('pico', 0.08770831674337387),
#  ('comer', 0.07542780786752701),
#  ('a', 0.06596854329109192),
#  ('media', 0.0632668286561966),
#  ('tierra', 0.06132807210087776),
#  ('real', 0.059047237038612366),
#  ('caballo', 0.05429970100522041)]

# %% [markdown]
# Ventana grande

# %%
pprint(kvs_bg.wv.most_similar(palabra, topn=10))
# Out:
# [('corteza', 0.11744938045740128),
#  ('brava', 0.1010819524526596),
#  ('raja', 0.089331716299057),
#  ('pico', 0.08919580280780792),
#  ('comer', 0.07508322596549988),
#  ('a', 0.06664954125881195),
#  ('media', 0.06376087665557861),
#  ('tierra', 0.06001744046807289),
#  ('real', 0.05938751995563507),
#  ('caballo', 0.054014306515455246)]

# %%
pprint(kvs_bg.wv.most_similar("chorizo", topn=100))
