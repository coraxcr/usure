# %%
import sys
import os
from pprint import pprint
sys.path.append(os.path.abspath("../../../"))
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from usure.wordvectors.infrastructure import FileKeyedVectorsRep
from usure.wordvectors.ui import StatisticsReporter
from usure.config import config

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = lines => false

# %%
display(HTML("""<style>.output { display: flex;align-items: center;text-align: center; } </style>"""))
# Out:
# <style>.output { display: flex;align-items: center;text-align: center; } </style>

# %%
kvs_rep = FileKeyedVectorsRep(config.embeddings)
# %matplotlib notebook

# %% [markdown]
# # 1. Corpus:  Facebook2013

# %%
kvs_sw = kvs_rep.get("CorpusFBCR2013.txt.usu.2_w.kvs")
kvs_bg = kvs_rep.get("CorpusFBCR2013.txt.usu.5_w.kvs")
reporter_sw = StatisticsReporter(kvs_sw)
reporter_bw = StatisticsReporter(kvs_bg)

# %% [markdown]
# ## 1.1 Histograma

# %%
reporter_sw.plot_histogram(numb_top_words=65)
# Out:
# <img src="data:image/png;base64,..." width="1299.9999718232596">

# %% [markdown]
# ## 1.2 Nube de palabras

# %%
reporter_sw.plot_wordcloud(max_words=250)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# ## 1.3 Representacion vectorial en 2D

# %%
numb_words = 500
reporter_sw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
reporter_bw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="1296">

# %% [markdown]
# ## 1.4 Similitudes entre palabras

# %% [markdown]
# Ventanas pequeñas

# %%
palabra = "madre"
pprint(kvs_sw.wv.most_similar(palabra, topn=10))
# Out:
# [('pario', 0.5636239647865295),
#  ('mama', 0.5525745153427124),
#  ('placenta', 0.5443602204322815),
#  ('crio', 0.5348185300827026),
#  ('soltera', 0.5285720825195312),
#  ('putisima', 0.5236702561378479),
#  ('diarreicamente', 0.519874095916748),
#  ('aguela', 0.5178878903388977),
#  ('pxta', 0.5150814056396484),
#  ('reputa', 0.5120619535446167)]

# %% [markdown]
# Ventana grande

# %%
pprint(kvs_bg.wv.most_similar(palabra, topn=10))
# Out:
# [('mama', 0.6032969951629639),
#  ('pario', 0.5887528657913208),
#  ('crio', 0.5738892555236816),
#  ('reputa', 0.5672279596328735),
#  ('soltera', 0.5667480826377869),
#  ('hijo', 0.5623704195022583),
#  ('padre', 0.5623667240142822),
#  ('diarreicamente', 0.5609269738197327),
#  ('placenta', 0.5602832436561584),
#  ('progenitora', 0.558624267578125)]

# %%
pprint(kvs_bg.wv.most_similar("chorizo", topn=100))
# Out:
# [('chorizoo', 0.7023618221282959),
#  ('choriso', 0.6778109073638916),
#  ('chorizos', 0.640501856803894),
#  ('chori', 0.6306802034378052),
#  ('embutido', 0.6136274337768555),
#  ('chorizaso', 0.6051105856895447),
#  ('chorizote', 0.6014155149459839),
#  ('casisa', 0.5946041345596313),
#  ('choripeaje', 0.5924298763275146),
#  ('megachorizo', 0.5884907841682434),
#  ('chorrizo', 0.585254430770874),
#  ('chorizon', 0.5822997093200684),
#  ('chirizo', 0.581798255443573),
#  ('chorizazo', 0.5807788968086243),
#  ('choricito', 0.5797514915466309),
#  ('choriz', 0.5784305334091187),
#  ('negocito', 0.5734136700630188),
#  ('chorii', 0.5729042291641235),
#  ('ciernes', 0.569099485874176),
#  ('hsolis', 0.568213939666748),
#  ('choricillo', 0.5682125687599182),
#  ('choris', 0.5670026540756226),
#  ('robadera', 0.5664294362068176),
#  ('narcoavionetas', 0.5634412169456482),
#  ('chorilandia', 0.5620513558387756),
#  ('festin', 0.5619967579841614),
#  ('destape', 0.5619887113571167),
# ...
