# %%
import sys
import os
from pprint import pprint
sys.path.append(os.path.abspath("../../../"))
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from usure.wordvectors.infrastructure import Word2VecDAO
from usure.wordvectors.ui import StatisticsReporter

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = lines => false

# %%
display(HTML("""<style>.output { display: flex;align-items: center;text-align: center; } </style>"""))
# Out:
# <style>.output { display: flex;align-items: center;text-align: center; } </style>

# %%
w2v_dao = Word2VecDAO()
# %matplotlib notebook

# %% [markdown]
# # 1. Corpus:  Facebook2013

# %%
w2v_sw = w2v_dao.get_model("CorpusFBCR2013.sw.w2v")
w2v_bg = w2v_dao.get_model("CorpusFBCR2013.bw.w2v")
reporter_sw = StatisticsReporter(w2v_sw.wv)
reporter_bw = StatisticsReporter(w2v_bg.wv)

# %% [markdown]
# ## 1.1 Histograma

# %%
reporter_sw.plot_histogram(numb_top_words=65)
# Out:
# <img src="data:image/png;base64,..." width="1300">

# %% [markdown]
# ## 1.2 Nube de palabras

# %%
reporter_sw.plot_wordcloud(max_words=250)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# ## 1.3 Representacion vectorial en 2D

# %%
numb_words = 500
reporter_sw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
reporter_bw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 1.4 Similitudes entre palabras

# %% [markdown]
# Ventanas pequeñas

# %%
palabra = "virtudes"
pprint(w2v_sw.wv.most_similar(palabra, topn=10))
# Out:
# [('defectos', 0.589546799659729),
#  ('cualidades', 0.5241401195526123),
#  ('debilidades', 0.4745296835899353),
#  ('reconocer', 0.4260910153388977),
#  ('imitarlas', 0.4029350280761719),
#  ('errores', 0.40146511793136597),
#  ('humildad', 0.3921473026275635),
#  ('reconocerlas', 0.3878510594367981),
#  ('desarrollemos', 0.38605374097824097),
#  ('selecionado', 0.37814244627952576)]

# %% [markdown]
# Ventana grande

# %%
pprint(w2v_bg.wv.most_similar(palabra, topn=10))
# Out:
# [('defectos', 0.6187158823013306),
#  ('cualidades', 0.4985969066619873),
#  ('imitarlas', 0.45089244842529297),
#  ('debilidades', 0.41837722063064575),
#  ('depreciar', 0.416745662689209),
#  ('reconocer', 0.4046350121498108),
#  ('reconocerlas', 0.3837417960166931),
#  ('reconoce', 0.37186747789382935),
#  ('errores', 0.36979731917381287),
#  ('expriencia', 0.36885613203048706)]
