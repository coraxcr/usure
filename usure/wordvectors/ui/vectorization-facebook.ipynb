# %%
import sys
import os
from pprint import pprint
sys.path.append(os.path.abspath("../../../"))
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from usure.wordvectors.infrastructure import FileKeyedVectorsRep
from usure.wordvectors.ui import StatisticsReporter
from usure.config import config

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = lines => false

# %%
display(HTML("""<style>.output { display: flex;align-items: center;text-align: center; } </style>"""))
# Out:
# <style>.output { display: flex;align-items: center;text-align: center; } </style>

# %%
kvs_rep = FileKeyedVectorsRep(config.embeddings)
# %matplotlib notebook

# %% [markdown]
# # 1. Corpus:  Facebook2013

# %%
kvs_sw = kvs_rep.get("CorpusFBCR2013.txt.usu.sw.kvs")
kvs_bg = kvs_rep.get("CorpusFBCR2013.txt.usu.bw.kvs")
reporter_sw = StatisticsReporter(kvs_sw)
reporter_bw = StatisticsReporter(kvs_bg)

# %% [markdown]
# ## 1.1 Histograma

# %%
reporter_sw.plot_histogram(numb_top_words=65)
# Out:
# <img src="data:image/png;base64,..." width="1300">

# %% [markdown]
# ## 1.2 Nube de palabras

# %%
reporter_sw.plot_wordcloud(max_words=250)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# ## 1.3 Representacion vectorial en 2D

# %%
numb_words = 500
reporter_sw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="1172">

# %%
reporter_bw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="1296">

# %% [markdown]
# ## 1.4 Similitudes entre palabras

# %% [markdown]
# Ventanas pequeñas

# %%
palabra = "virtudes"
pprint(kvs_sw.wv.most_similar(palabra, topn=10))
# Out:
# [('defectos', 0.609201967716217),
#  ('cualidades', 0.48270413279533386),
#  ('debilidades', 0.4783068299293518),
#  ('imitarlas', 0.44339612126350403),
#  ('reconocerlas', 0.4241964519023895),
#  ('reconocer', 0.4039601683616638),
#  ('selecionado', 0.38545483350753784),
#  ('errores', 0.38192030787467957),
#  ('depreciar', 0.3749372363090515),
#  ('veniales', 0.3646702170372009)]

# %% [markdown]
# Ventana grande

# %%
pprint(kvs_bg.wv.most_similar(palabra, topn=10))
# Out:
# [('defectos', 0.6583178043365479),
#  ('debilidades', 0.49276068806648254),
#  ('cualidades', 0.48431169986724854),
#  ('imitarlas', 0.43712764978408813),
#  ('reconocer', 0.4369501769542694),
#  ('cometemos', 0.4079771041870117),
#  ('errores', 0.39497286081314087),
#  ('depreciar', 0.3825494050979614),
#  ('reconocerlas', 0.36973345279693604),
#  ('veniales', 0.3688056468963623)]
