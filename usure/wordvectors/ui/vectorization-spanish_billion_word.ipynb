# %%
import sys
import os
from pprint import pprint
sys.path.append(os.path.abspath("../../../"))
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from usure.wordvectors.infrastructure import FileKeyedVectorsRep
from usure.wordvectors.ui import StatisticsReporter
from usure.config import config

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = lines => false

# %%
display(HTML("""<style>.output { display: flex;align-items: center;text-align: center; } </style>"""))
# Out:
# <style>.output { display: flex;align-items: center;text-align: center; } </style>

# %%
kvs_rep = FileKeyedVectorsRep(config.embeddings)
# %matplotlib notebook

# %% [markdown]
# # 1. Corpus:  Cardellino one billion corpus

# %%
kvs = kvs_rep.get("SBW-vectors-300-min5.bin")#SBW-vectors-300-min5.bin
reporter_sw = StatisticsReporter(kvs)

# %% [markdown]
# ## 1.1 Histograma

# %%
reporter_sw.plot_histogram(numb_top_words=65)
# Out:
# <img src="data:image/png;base64,..." width="1300">

# %% [markdown]
# ## 1.2 Nube de palabras

# %%
reporter_sw.plot_wordcloud(max_words=250)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# ## 1.3 Representacion vectorial en 2D

# %%
numb_words = 500
reporter_sw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="1121">

# %%
reporter_sw.plot_scatter(numb_words=numb_words, num_dim=2)
# Out:
# <img src="data:image/png;base64,..." width="1187">

# %% [markdown]
# ## 1.4 Similitudes entre palabras

# %% [markdown]
# Unica ventana

# %%
palabra = "virtudes"
kvs.most_similar(palabra, topn=10)
# Out:
# [('cualidades', 0.7517346143722534),
#  ('teologales', 0.6700092554092407),
#  ('infusas', 0.6544116735458374),
#  ('acrisoladas', 0.6489577293395996),
#  ('dianoéticas', 0.6480014324188232),
#  ('bondad', 0.6453606486320496),
#  ('sofrosine', 0.6367048621177673),
#  ('templanza', 0.624442994594574),
#  ('sabiduría', 0.6187539100646973),
#  ('flaquezas', 0.6129355430603027)]

# %%
kvs.vocab["parte"].count
# Out:
# 1000609

# %%
kvs.most_similar("virtudes", topn=10)
# Out:
# [('cualidades', 0.7517346143722534),
#  ('teologales', 0.6700092554092407),
#  ('infusas', 0.6544116735458374),
#  ('acrisoladas', 0.6489577293395996),
#  ('dianoéticas', 0.6480014324188232),
#  ('bondad', 0.6453606486320496),
#  ('sofrosine', 0.6367048621177673),
#  ('templanza', 0.624442994594574),
#  ('sabiduría', 0.6187539100646973),
#  ('flaquezas', 0.6129355430603027)]
